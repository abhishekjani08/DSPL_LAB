# %%
#importing the pandas and numpy library
import pandas as pd
import numpy as np

# %%
#reading the csv file
dataframe = pd.read_csv("House_Rent_main1.csv")

# %%
#printing the number of samples and attributes of dataset
print(dataframe.shape)
# Out:
# (4746, 9)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4746 non-null   int64
#  1   Rent               4746 non-null   int64
#  2   Size               4746 non-null   int64
#  3   Area Type          4746 non-null   int64
#  4   Area Locality      4746 non-null   object
#  5   City               4746 non-null   object
#  6   Furnishing Status  4746 non-null   int64
#  7   Tenant Preferred   4746 non-null   object
#  8   Bathroom           4746 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 333.8+ KB

# %%
dataframe
# Out:
#       BHK   Rent  Size  Area Type             Area Locality       City  \
# 0       2  10000  1100          1                    Bandel    Kolkata
# 1       2  20000   800          1  Phool Bagan, Kankurgachi    Kolkata
# 2       2  17000  1000          1   Salt Lake City Sector 2    Kolkata
# 3       2  10000   800          1               Dumdum Park    Kolkata
# 4       2   7500   850          2             South Dum Dum    Kolkata
# ...   ...    ...   ...        ...                       ...        ...
# 4741    2  15000  1000          2              Bandam Kommu  Hyderabad
# 4742    3  29000  2000          1      Manikonda, Hyderabad  Hyderabad
# 4743    3  35000  1750          2      Himayath Nagar, NH 7  Hyderabad
# 4744    3  45000  1500          2                Gachibowli  Hyderabad
# 4745    2  15000  1000          2           Suchitra Circle  Hyderabad
#
#       Furnishing Status  Tenant Preferred  Bathroom
# 0                     1  Bachelors/Family         2
# ...

# %%
# replacing the Furninshing status
dataframe.replace({"Unfurnished" : "1" , "Furnished": "2" , "Semi-Furnished" : "3"},inplace = True)
dataframe.replace({"Bachelors/Family" : "1" , "Bachelors": "2" , "Family" : "3"},inplace = True)
dataframe.replace({"Kolkata" : "1" , "Mumbai": "2" , "Delhi" : "3", "Chennai" : "4", "Bangalore" : "5", "Hyderabad" : "6"},inplace = True)
print(dataframe.shape)
dataframe
# Out:
# (4746, 9)
#       BHK   Rent  Size  Area Type             Area Locality City  \
# 0       2  10000  1100          1                    Bandel    1
# 1       2  20000   800          1  Phool Bagan, Kankurgachi    1
# 2       2  17000  1000          1   Salt Lake City Sector 2    1
# 3       2  10000   800          1               Dumdum Park    1
# 4       2   7500   850          2             South Dum Dum    1
# ...   ...    ...   ...        ...                       ...  ...
# 4741    2  15000  1000          2              Bandam Kommu    6
# 4742    3  29000  2000          1      Manikonda, Hyderabad    6
# 4743    3  35000  1750          2      Himayath Nagar, NH 7    6
# 4744    3  45000  1500          2                Gachibowli    6
# 4745    2  15000  1000          2           Suchitra Circle    6
#
#       Furnishing Status Tenant Preferred  Bathroom
# 0                     1                1         2
# 1                     2                1         1
# ...

# %%
#plotting a bar graph
import matplotlib.pyplot as plt
dataframe = dataframe
dataframe.plot(x="BHK", y="Bathroom", kind="bar")
# Out:
# <Axes: xlabel='BHK'>

# %%
#plotting a pie chart
import matplotlib.pyplot as plt
# Plotting the pie chart for above dataframe
new_dataframe.groupby(['BHK']).sum().plot(kind='pie', y='Rent', autopct='%1.0f%%')
new_dataframe.groupby(['Bathroom']).sum().plot(kind='pie', y='Size', autopct='%1.0f%%')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9784\3278239948.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_dataframe.groupby(['BHK']).sum().plot(kind='pie', y='Rent', autopct='%1.0f%%')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9784\3278239948.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_dataframe.groupby(['Bathroom']).sum().plot(kind='pie', y='Size', autopct='%1.0f%%')
# <Axes: ylabel='Size'>

# %%
#plotting a histogram for number's of BHK's
plt.hist(new_dataframe['BHK'])
plt.xlabel("BHK")
# Out:
# Text(0.5, 0, 'BHK')

# %%
# Syntax of boxplot()
new_dataframe.boxplot(column=None, by=None, ax=None, fontsize=None, rot=0, grid=True, figsize=None, layout=None)
# Out:
# <Axes: >

# %%
# Syntax of scatter plot()
plt.scatter(new_dataframe['BHK'], new_dataframe['Rent'])
plt.xlabel("BHK")
plt.ylabel("Rent")
plt.show()

# %%
#OUTLIERS

# %%
import seaborn as sns
# compare plots before trimming
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataframe['BHK'])
plt.subplot(2,2,2)
sns.boxplot(dataframe['BHK'])
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9784\1166118190.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe['BHK'])

# %%
# finding boundary values for bmi using z-score
print("Highest allowed",dataframe['BHK'].mean() + 3*dataframe['BHK'].std())
print("Lowest allowed",dataframe['BHK'].mean() - 3*dataframe['BHK'].std())
# Out:
# Highest allowed 4.58062778809999
# Lowest allowed -0.41290760268068993

# %%
# finding outliers for bmi
dataframe[(dataframe['BHK'] > 4.580627788100002) | (dataframe['BHK'] < -0.4129076026807015)]
# Out:
#       BHK    Rent  Size  Area Type                           Area Locality  \
# 83      6   20000  1000          1                                Sonarpur
# 460     5   22500   960          1                                   Kasba
# 521     5   25000  1880          2                               Dashdrone
# 543     5  400000  2308          2           Runwal Elegante, Andheri West
# 666     5  350000  1880          2           Runwal Elegante, Andheri West
# 792     5  600000  3200          2                             Bandra East
# 839     5  450000  3400          2                             Bandra West
# 848     5  300000  3000          2                              Chandivali
# 1023    5  500000  3900          2                          Altamount Road
# 1037    5  350000  3250          2                                  Deonar
# 1287    5  360000  1880          2           Runwal Elegante, Andheri West
# ...

# %%
# Trimming of outliers for bmi
df2 = dataframe[(dataframe['BHK'] < 4.580627788100002) & (dataframe['BHK'] > -0.4129076026807015)]
df2
# Out:
#       BHK   Rent  Size  Area Type             Area Locality City  \
# 0       2  10000  1100          1                    Bandel    1
# 1       2  20000   800          1  Phool Bagan, Kankurgachi    1
# 2       2  17000  1000          1   Salt Lake City Sector 2    1
# 3       2  10000   800          1               Dumdum Park    1
# 4       2   7500   850          2             South Dum Dum    1
# ...   ...    ...   ...        ...                       ...  ...
# 4741    2  15000  1000          2              Bandam Kommu    6
# 4742    3  29000  2000          1      Manikonda, Hyderabad    6
# 4743    3  35000  1750          2      Himayath Nagar, NH 7    6
# 4744    3  45000  1500          2                Gachibowli    6
# 4745    2  15000  1000          2           Suchitra Circle    6
#
#       Furnishing Status Tenant Preferred  Bathroom
# 0                     1                1         2
# 1                     2                1         1
# ...

# %%
# compare plots after trimming
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df2['BHK'])
plt.subplot(2,2,2)
sns.boxplot(df2['BHK'])
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9784\2669759961.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['BHK'])

# %%
cat_cols=["Area Locality"]
df2_encoded=pd.get_dummies(df2,columns=cat_cols)
df2_encoded
# Out:
#       BHK   Rent  Size  Area Type City  Furnishing Status Tenant Preferred  \
# 0       2  10000  1100          1    1                  1                1
# 1       2  20000   800          1    1                  2                1
# 2       2  17000  1000          1    1                  2                1
# 3       2  10000   800          1    1                  1                1
# 4       2   7500   850          2    1                  1                2
# ...   ...    ...   ...        ...  ...                ...              ...
# 4741    2  15000  1000          2    6                  2                1
# 4742    3  29000  2000          1    6                  2                1
# 4743    3  35000  1750          2    6                  2                1
# 4744    3  45000  1500          2    6                  2                3
# 4745    2  15000  1000          2    6                  1                2
#
# ...

# %%
#We are applying Regression Model on our dataset

# %%
df = pd.read_csv('House_Rent_main7.csv')
data= df
#splitting data
from sklearn.model_selection import train_test_split
x = np.array(data[["BHK", "Size", "Area Type", "City", 
                   "Furnishing Status", "Tenant Preferred", 
                   "Bathroom"]])
y = np.array(data[["Rent"]])

xtrain, xtest, ytrain, ytest = train_test_split(x, y, 
                                                test_size=0.10, 
                                                random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
#We are using Decision Tree Regressor

# %%
from sklearn.metrics import accuracy_score

clf = DecisionTreeRegressor()
clf.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
ypred = clf.predict(xtest)

# %%
print("Decision Tree Regressor: ")
r2_score(ytest, ypred)
# Out:
# Decision Tree Regressor:
# 0.9356577360169804

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
model = Sequential()
model.add(LSTM(128, return_sequences=True, 
               input_shape= (xtrain.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_6 (LSTM)               (None, 7, 128)            66560
#
#  lstm_7 (LSTM)               (None, 64)                49408
#
#  dense_6 (Dense)             (None, 25)                1625
#
#  dense_7 (Dense)             (None, 1)                 26
#
# ...
# Total params: 117,619
# Trainable params: 117,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression 
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(xtrain, ytrain, batch_size=1, epochs=22)
# Out:
# Epoch 1/22
# 4247/4247 [==============================] - 38s 8ms/step - loss: 6991124992.0000
# Epoch 2/22
# 4247/4247 [==============================] - 36s 8ms/step - loss: 6438268416.0000
# Epoch 3/22
# 4247/4247 [==============================] - 36s 8ms/step - loss: 6145740288.0000
# Epoch 4/22
# 4247/4247 [==============================] - 35s 8ms/step - loss: 5956031488.0000
# Epoch 5/22
# 4247/4247 [==============================] - 36s 8ms/step - loss: 5767700992.0000
# Epoch 6/22
# 4247/4247 [==============================] - 35s 8ms/step - loss: 5607872512.0000
# Epoch 7/22
# 4247/4247 [==============================] - 35s 8ms/step - loss: 5490118656.0000
# Epoch 8/22
# 4247/4247 [==============================] - 31s 7ms/step - loss: 5451380224.0000
# Epoch 9/22
# 4247/4247 [==============================] - 33s 8ms/step - loss: 5303410176.0000
# Epoch 10/22
# 4247/4247 [==============================] - 32s 8ms/step - loss: 5081030656.0000
# Epoch 11/22
# ...

# %%
print("Enter House Details to Predict Rent")
a = int(input("Number of BHK: "))
b = int(input("Size of the House: "))
c = int(input("Area Type (Super Area = 1, Carpet Area = 2, Built Area = 3): "))
d = int(input("Pin Code of the City: "))
e = int(input("Furnishing Status of the House (Unfurnished = 0, Semi-Furnished = 1, Furnished = 2): "))
f = int(input("Tenant Type (Bachelors = 1, Bachelors/Family = 2, Only Family = 3): "))
g = int(input("Number of bathrooms: "))
features = np.array([[a, b, c, d, e, f, g]])
print("Predicted House Rent = ", clf.predict(features))
print("Predicted House Rent = ", model.predict(features))
# Out:
# Enter House Details to Predict Rent
# Number of BHK: 2
# Size of the House: 2000
# Area Type (Super Area = 1, Carpet Area = 2, Built Area = 3): 1
# Pin Code of the City: 2
# Furnishing Status of the House (Unfurnished = 0, Semi-Furnished = 1, Furnished = 2): 2
# Tenant Type (Bachelors = 1, Bachelors/Family = 2, Only Family = 3): 2
# Number of bathrooms: 1
# Predicted House Rent =  [350000.]
# Predicted House Rent =  [[36929.527]]

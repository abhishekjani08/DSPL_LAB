# %%
#import dependencies
import pandas as pd
import numpy as np
import imblearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('House_Rent_main3.csv')
df1=df
df1.sample(5)
# Out:
#       Unnamed: 0   Posted On  BHK   Rent  Size            Floor Area Type  \
# 2611        2625  2022-04-29    3  12500   650       3 out of 4         1
# 912          920  2022-06-15    1  75000   575       1 out of 9         2
# 4207        4228  2022-05-20    2   9000   100       2 out of 3         1
# 3537        3554  2022-05-25    3  26000  2100       1 out of 4         1
# 1138        1148  2022-04-29    2  50000   750  Ground out of 5         1
#
#        Area Locality       City  Furnishing Status  Tenant Preferred  Bathroom
# 2611    Chirag Delhi          4                  2  Bachelors/Family         1
# 912     Malabar Hill          2                  2            Family         1
# 4207    Chanchalguda  Hyderabad                  1  Bachelors/Family         2
# 3537  Sholinganallur          5                  2  Bachelors/Family         2
# 1138      D.N. Nagar          2                  1  Bachelors/Family         2

# %%
df1.replace(to_replace="Hyderabad",
           value="6")
# Out:
#       Unnamed: 0   Posted On  BHK   Rent  Size            Floor Area Type  \
# 0              0  2022-05-18    2  10000  1100  Ground out of 2         1
# 1              1  2022-05-13    2  20000   800       1 out of 3         1
# 2              2  2022-05-16    2  17000  1000       1 out of 3         1
# 3              3  2022-07-04    2  10000   800       1 out of 2         1
# 4              4  2022-05-09    2   7500   850       1 out of 2         2
# ...          ...         ...  ...    ...   ...              ...       ...
# 4714        4741  2022-05-18    2  15000  1000       3 out of 5         2
# 4715        4742  2022-05-15    3  29000  2000       1 out of 4         1
# 4716        4743  2022-07-10    3  35000  1750       3 out of 5         2
# 4717        4744  2022-07-06    3  45000  1500     23 out of 34         2
# 4718        4745  2022-05-04    2  15000  1000       4 out of 5         2
#
#                  Area Locality City  Furnishing Status  Tenant Preferred  \
# 0                       Bandel    1                  1  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    1                  2  Bachelors/Family
# 2      Salt Lake City Sector 2    1                  2  Bachelors/Family
# 3                  Dumdum Park    1                  1  Bachelors/Family
# 4                South Dum Dum    1                  1         Bachelors
# ...                        ...  ...                ...               ...
# 4714              Bandam Kommu    6                  2  Bachelors/Family
# 4715      Manikonda, Hyderabad    6                  2  Bachelors/Family
# 4716      Himayath Nagar, NH 7    6                  2  Bachelors/Family
# 4717                Gachibowli    6                  2            Family
# 4718           Suchitra Circle    6                  1         Bachelors
#
#       Bathroom
# 0            2
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 4714         2
# 4715         3
# 4716         3
# 4717         2
# 4718         2
#
# [4719 rows x 12 columns]

# %%
print(df1["BHK"].unique())
# Out:
# [2 1 3 4]

# %%
#Describing data after preprocessing 
print(df1.shape)
# Out:
# (4719, 12)

# %%
df1.BHK.value_counts()
plt.figure(figsize=(6,6))
sns.countplot(x='BHK', data=df1)
plt.title('BHK Label')
plt.show()
